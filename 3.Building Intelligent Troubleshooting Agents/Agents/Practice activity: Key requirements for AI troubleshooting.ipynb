# %%
knowledge_base = {
    "slow_internet": {
        "symptom": "My internet is very slow.",
        "solution": "Try restarting your router and checking your connection settings."
    },
    "app_crashing": {
        "symptom": "The app keeps crashing on startup.",
        "solution": "Update the app to the latest version and restart your device."
    },
    "computer_not_turning_on": {
        "symptom": "My computer won't turn on at all.",
        "solution": "Check that the power cable is securely connected, try a different outlet, and hold the power button for 10 seconds to perform a hard reset."
    },
    "bluetooth_not_connecting": {
        "symptom": "My Bluetooth device won't connect to my computer.",
        "solution": "Turn Bluetooth off and on again, remove the device from paired devices and re-pair it, and ensure the device is in pairing mode."
    },
    "printer_not_printing": {
        "symptom": "My printer is connected but won't print anything.",
        "solution": "Check for paper jams, ensure there is enough ink or toner, restart the print spooler service, and try removing and re-adding the printer."
    },
    "email_not_syncing": {
        "symptom": "My email is not syncing or receiving new messages.",
        "solution": "Verify your internet connection, check your email account credentials, ensure the mail server settings are correct, and try removing and re-adding the email account."
    },
    "screen_flickering": {
        "symptom": "My computer screen keeps flickering or going black intermittently.",
        "solution": "Update your graphics drivers, check the display cable connections, adjust the refresh rate in display settings, and test with a different monitor if available."
    }
}

# %%
type(knowledge_base)
# Out:
# dict

# %%
import json
##from transformers import pipeline

# Load knowledge base
# with open('troubleshooting_knowledge_base.json', 'r') as f:
#     knowledge_base = json.load(f)

# Initialize a simple NLP model
#nlp = pipeline('question-answering')

# Get user input
user_input = input("Please describe your problem: ")

# Search knowledge base for a simple text-based match
for issue, details in knowledge_base.items():
    if details["symptom"].lower() in user_input.lower():
        print(f"Possible solution: {details['solution']}")
        break
else:
    print("No matching issue found in the knowledge base.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
def diagnose_network_issue():
    print("Have you restarted your router?")
    response = input("Yes/No: ").strip().lower()
    if response == "no":
        print("Please restart your router and check again.")
    else:
        print("Try resetting your network settings or contacting your provider.")

# Trigger diagnostic logic if the issue is related to the network
if "internet" in user_input.lower():
    diagnose_network_issue()
# Out:
# pip 25.3 from /Users/oceansxyz/Library/Python/3.9/lib/python/site-packages/pip (python 3.9)

# %%
def automate_fix(issue):
    if issue == "slow_internet":
        print("Resetting network settings...")
        # Simulated network reset
        print("Network settings have been reset. Please check your connection.")
    else:
        print("Automation is not available for this issue.")

# Simulate automatic fix
if "internet" in user_input.lower():
    automate_fix("slow_internet")

# %%
def collect_feedback():
    feedback = input("Did this solution resolve your issue? (Yes/No): ").strip().lower()
    if feedback == "yes":
        print("Great! Your feedback has been recorded.")
    else:
        print("We're sorry the issue persists. We'll improve our solution based on your input.")

# Collect feedback after providing a solution
collect_feedback()
# Out:
# We're sorry the issue persists. We'll improve our solution based on your input.
